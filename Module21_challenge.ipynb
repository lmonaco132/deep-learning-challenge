# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['EIN', 'NAME'], axis=1)

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T9', 'T13', 'T12', 'T2', 'T14', 'T25', 'T15', 'T29', 'T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
application_df['CLASSIFICATION'].value_counts().index
# Out:
# Index(['C1000', 'C2000', 'C1200', 'C3000', 'C2100', 'C7000', 'C1700', 'C4000',
#        'C5000', 'C1270', 'C2700', 'C2800', 'C7100', 'C1300', 'C1280', 'C1230',
#        'C1400', 'C7200', 'C2300', 'C1240', 'C8000', 'C7120', 'C1500', 'C1800',
#        'C6000', 'C1250', 'C8200', 'C1238', 'C1278', 'C1235', 'C1237', 'C7210',
#        'C2400', 'C1720', 'C4100', 'C1257', 'C1600', 'C1260', 'C2710', 'C0',
#        'C3200', 'C1234', 'C1246', 'C1267', 'C1256', 'C2190', 'C4200', 'C2600',
#        'C5200', 'C1370', 'C1248', 'C6100', 'C1820', 'C1900', 'C1236', 'C3700',
#        'C2570', 'C1580', 'C1245', 'C2500', 'C1570', 'C1283', 'C2380', 'C1732',
#        'C1728', 'C2170', 'C4120', 'C8210', 'C2561', 'C4500', 'C2150'],
#       dtype='object')

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = ['C7000', 'C1700', 'C4000',
       'C5000', 'C1270', 'C2700', 'C2800', 'C7100', 'C1300', 'C1280', 'C1230',
       'C1400', 'C7200', 'C2300', 'C1240', 'C8000', 'C7120', 'C1500', 'C1800',
       'C6000', 'C1250', 'C8200', 'C1238', 'C1278', 'C1235', 'C1237', 'C7210',
       'C2400', 'C1720', 'C4100', 'C1257', 'C1600', 'C1260', 'C2710', 'C0',
       'C3200', 'C1234', 'C1246', 'C1267', 'C1256', 'C2190', 'C4200', 'C2600',
       'C5200', 'C1370', 'C1248', 'C6100', 'C1820', 'C1900', 'C1236', 'C3700',
       'C2570', 'C1580', 'C1245', 'C2500', 'C1570', 'C1283', 'C2380', 'C1732',
       'C1728', 'C2170', 'C4120', 'C8210', 'C2561', 'C4500', 'C2150']

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL']
X = application_df.drop('IS_SUCCESSFUL', axis=1)

# Convert categorical data to numeric with `pd.get_dummies`
# YOUR CODE GOES HERE
X = pd.get_dummies(X)
X.head()

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  10
hidden_nodes_layer2 = 7

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 10)                440
#
#  dense_4 (Dense)             (None, 7)                 77
#
#  dense_5 (Dense)             (None, 1)                 8
#
# ...
# Total params: 525 (2.05 KB)
# Trainable params: 525 (2.05 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6150 - accuracy: 0.6812
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5703 - accuracy: 0.7199
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5625 - accuracy: 0.7237
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5585 - accuracy: 0.7271
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5554 - accuracy: 0.7290
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5537 - accuracy: 0.7290
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5525 - accuracy: 0.7286
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5516 - accuracy: 0.7290
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7303
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5542 - accuracy: 0.7307 - 387ms/epoch - 1ms/step
# Loss: 0.5542436242103577, Accuracy: 0.7307288646697998

# %%
# Optimizing the model (first attempt)

# trying removing another column which seems less relevant
application_df_new = application_df.drop('ORGANIZATION', axis=1)

# repeating data processing with this dataframe
# Split our preprocessed data into our features and target arrays
y_1 = application_df_new['IS_SUCCESSFUL']
X_1 = application_df_new.drop('IS_SUCCESSFUL', axis=1)

# Convert categorical data to numeric with `pd.get_dummies`
# YOUR CODE GOES HERE
X_1 = pd.get_dummies(X_1)
X_1.head()

# Split the preprocessed data into a training and testing dataset
X1_train, X1_test, y1_train, y1_test = train_test_split(X_1, y_1, random_state=1)

# Standard Scaler
scaler = StandardScaler()

# Fit the StandardScaler
X1_scaler = scaler.fit(X1_train)

# Scale the data
X1_train_scaled = X1_scaler.transform(X1_train)
X1_test_scaled = X1_scaler.transform(X1_test)

# %%
# Define the model - same model as before, first optimization change is removing one potentially irrelevant predictor
number_input_features = len(X1_train_scaled[0])
hidden_nodes_layer1 =  10
hidden_nodes_layer2 = 7

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# fit the model
fit_model = nn.fit(X1_train_scaled,y1_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6080 - accuracy: 0.6966
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5713 - accuracy: 0.7208
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5660 - accuracy: 0.7233
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5637 - accuracy: 0.7248
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5628 - accuracy: 0.7248
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5619 - accuracy: 0.7260
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5609 - accuracy: 0.7265
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5603 - accuracy: 0.7279
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5601 - accuracy: 0.7263
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X1_test_scaled,y1_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5630 - accuracy: 0.7250 - 401ms/epoch - 1ms/step
# Loss: 0.5630334615707397, Accuracy: 0.7250145673751831

# %%
# Optimizing the model (second attempt)
# first attempt had slightly lower accuracy, so we will use the original data with all features
# trying to increase the number of neurons in the hidden layers

# Define the model - now with more neurons in the hidden layers
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  12
hidden_nodes_layer2 = 9

nn_1 = tf.keras.models.Sequential()

# First hidden layer
nn_1.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn_1.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn_1.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Compile the model
nn_1.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# fit the model
fit_model_1 = nn_1.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5955 - accuracy: 0.7056
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5614 - accuracy: 0.7265
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5577 - accuracy: 0.7280
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5553 - accuracy: 0.7281
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5542 - accuracy: 0.7287
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5530 - accuracy: 0.7306
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5519 - accuracy: 0.7309
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5516 - accuracy: 0.7312
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5508 - accuracy: 0.7304
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5534 - accuracy: 0.7283 - 471ms/epoch - 2ms/step
# Loss: 0.5533730387687683, Accuracy: 0.7282798886299133

# %%
# Optimizing the model (third attempt)
# now I will try adding more epochs to the training of the model
# since the model with increased number of nodes actually performed slightly worse than the original, I will use the original model


# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  10
hidden_nodes_layer2 = 7

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# fit the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=150)
# Out:
# Epoch 1/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6361 - accuracy: 0.6306
# Epoch 2/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5662 - accuracy: 0.7260
# Epoch 3/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5581 - accuracy: 0.7278
# Epoch 4/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5550 - accuracy: 0.7305
# Epoch 5/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5531 - accuracy: 0.7303
# Epoch 6/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5518 - accuracy: 0.7313
# Epoch 7/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5507 - accuracy: 0.7307
# Epoch 8/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5506 - accuracy: 0.7310
# Epoch 9/150
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5496 - accuracy: 0.7315
# Epoch 10/150
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5549 - accuracy: 0.7285 - 635ms/epoch - 2ms/step
# Loss: 0.554932713508606, Accuracy: 0.7285131216049194

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
